# %%
import os
import numpy as np
from scipy.spatial.distance import cdist

def parse_file(file_path, n=20):
    instances = []
    with open(file_path, 'r') as f:
        for line in f:
            tokens = line.strip().split()
            if "output" in tokens:
                idx = tokens.index("output")
                tokens = tokens[:idx]  # output 이전까지만 자르기
            try:
                coords_flat = list(map(float, tokens))
                if len(coords_flat) == 2 * n:
                    coords = np.array(coords_flat).reshape((n, 2))
                    instances.append(coords)
            except ValueError:
                continue
    return instances

def parse_file_with_optimal_tour(file_path, n=20):
    instances = []
    with open(file_path, 'r') as f:
        for line in f:
            tokens = line.strip().split()
            if "output" in tokens:
                idx = tokens.index("output")
                coords_flat = list(map(float, tokens[:idx]))
                tour = [int(x) - 1 for x in tokens[idx + 1:]]
                if len(coords_flat) == 2 * n and len(tour) == n + 1:
                    coords = np.array(coords_flat).reshape((n, 2))
                    instances.append((coords, tour))
    return instances

def save_distance_matrix_with_tour_txt(coords, tour, file_path):
    n = coords.shape[0]
    dist_matrix = cdist(coords, coords)
    dist_values = []
    for i in range(n):
        for j in range(i + 1, n):
            dist_values.append(dist_matrix[i, j])
    with open(file_path, 'w') as f:
        for val in dist_values:
            f.write(f"{val} ")
        f.write("output ")
        for node in tour:
            f.write(f"{node + 1} ")  # 다시 1-indexed로 저장
        f.write("\n")

input_path = os.path.join("dataset", "hw_2_tsp_20.txt")
instances_with_tour = parse_file_with_optimal_tour(input_path)

for i, (coords, tour) in enumerate(instances_with_tour, 1):
    file_path = os.path.join("dataset", f"20-{i}.txt")
    save_distance_matrix_with_tour_txt(coords, tour, file_path)

# %%
import os
import time
import numpy as np

# 설정
node_counts = [10, 20, 30, 40, 50]
num_samples = 30000
seed = 1234

np.random.seed(seed)

for n in node_counts:
    # 폴더 준비
    inst_dir = f"data/TSP{n}/instances"
    os.makedirs(inst_dir, exist_ok=True)

    start_all = time.time()
    for idx in range(num_samples):
        # 1) 무작위 좌표 생성
        coords = np.random.random((n, 2)).astype(np.float32)  # [0,1]^2

        # 2) 파일명 (5자리 zero-pad)
        fname = f"{idx:05d}"

        # 3) 좌표만 저장
        np.savez_compressed(
            os.path.join(inst_dir, f"instance_{fname}.npz"),
            coords=coords
        )

        # 4) 진행 로그 (예: 1000개마다)
        if (idx + 1) % 1000 == 0:
            elapsed = time.time() - start_all
            print(f"TSP{n}: Created {idx+1}/{num_samples} instances, elapsed {elapsed:.1f}s")

    total_time = time.time() - start_all
    print(f"✔ Finished TSP{n}, generated {num_samples} instances in {total_time:.1f}s\n")
# Out:
# TSP10: Created 1000/30000 instances, elapsed 0.9s
# TSP10: Created 2000/30000 instances, elapsed 1.8s
# TSP10: Created 3000/30000 instances, elapsed 2.6s
# TSP10: Created 4000/30000 instances, elapsed 3.5s
# TSP10: Created 5000/30000 instances, elapsed 4.3s
# TSP10: Created 6000/30000 instances, elapsed 5.0s
# TSP10: Created 7000/30000 instances, elapsed 5.5s
# TSP10: Created 8000/30000 instances, elapsed 6.0s
# TSP10: Created 9000/30000 instances, elapsed 6.6s
# TSP10: Created 10000/30000 instances, elapsed 7.1s
# TSP10: Created 11000/30000 instances, elapsed 7.6s
# TSP10: Created 12000/30000 instances, elapsed 8.2s
# TSP10: Created 13000/30000 instances, elapsed 8.8s
# TSP10: Created 14000/30000 instances, elapsed 9.3s
# TSP10: Created 15000/30000 instances, elapsed 9.8s
# TSP10: Created 16000/30000 instances, elapsed 10.3s
# TSP10: Created 17000/30000 instances, elapsed 10.8s
# TSP10: Created 18000/30000 instances, elapsed 11.3s
# TSP10: Created 19000/30000 instances, elapsed 11.9s
# TSP10: Created 20000/30000 instances, elapsed 12.4s
# TSP10: Created 21000/30000 instances, elapsed 13.0s
# TSP10: Created 22000/30000 instances, elapsed 13.6s
# TSP10: Created 23000/30000 instances, elapsed 14.2s
# TSP10: Created 24000/30000 instances, elapsed 14.7s
# TSP10: Created 25000/30000 instances, elapsed 15.3s
# TSP10: Created 26000/30000 instances, elapsed 15.8s
# TSP10: Created 27000/30000 instances, elapsed 16.4s
# TSP10: Created 28000/30000 instances, elapsed 16.9s
# TSP10: Created 29000/30000 instances, elapsed 17.5s
# TSP10: Created 30000/30000 instances, elapsed 18.1s
# ✔ Finished TSP10, generated 30000 instances in 18.1s
#
# TSP20: Created 1000/30000 instances, elapsed 0.6s
# TSP20: Created 2000/30000 instances, elapsed 1.2s
# TSP20: Created 3000/30000 instances, elapsed 1.8s
# TSP20: Created 4000/30000 instances, elapsed 2.4s
# TSP20: Created 5000/30000 instances, elapsed 2.9s
# TSP20: Created 6000/30000 instances, elapsed 3.5s
# TSP20: Created 7000/30000 instances, elapsed 4.1s
# TSP20: Created 8000/30000 instances, elapsed 4.6s
# TSP20: Created 9000/30000 instances, elapsed 5.2s
# TSP20: Created 10000/30000 instances, elapsed 5.8s
# TSP20: Created 11000/30000 instances, elapsed 6.3s
# TSP20: Created 12000/30000 instances, elapsed 6.8s
# TSP20: Created 13000/30000 instances, elapsed 7.4s
# TSP20: Created 14000/30000 instances, elapsed 8.0s
# TSP20: Created 15000/30000 instances, elapsed 8.6s
# TSP20: Created 16000/30000 instances, elapsed 9.1s
# TSP20: Created 17000/30000 instances, elapsed 9.6s
# TSP20: Created 18000/30000 instances, elapsed 10.2s
# TSP20: Created 19000/30000 instances, elapsed 10.8s
# TSP20: Created 20000/30000 instances, elapsed 11.3s
# TSP20: Created 21000/30000 instances, elapsed 11.8s
# TSP20: Created 22000/30000 instances, elapsed 12.4s
# TSP20: Created 23000/30000 instances, elapsed 13.1s
# TSP20: Created 24000/30000 instances, elapsed 13.6s
# TSP20: Created 25000/30000 instances, elapsed 14.2s
# TSP20: Created 26000/30000 instances, elapsed 14.7s
# TSP20: Created 27000/30000 instances, elapsed 15.3s
# TSP20: Created 28000/30000 instances, elapsed 15.8s
# TSP20: Created 29000/30000 instances, elapsed 16.4s
# TSP20: Created 30000/30000 instances, elapsed 17.0s
# ✔ Finished TSP20, generated 30000 instances in 17.0s
#
# TSP30: Created 1000/30000 instances, elapsed 0.6s
# TSP30: Created 2000/30000 instances, elapsed 1.1s
# TSP30: Created 3000/30000 instances, elapsed 1.7s
# TSP30: Created 4000/30000 instances, elapsed 2.3s
# TSP30: Created 5000/30000 instances, elapsed 2.9s
# TSP30: Created 6000/30000 instances, elapsed 3.6s
# TSP30: Created 7000/30000 instances, elapsed 4.1s
# TSP30: Created 8000/30000 instances, elapsed 4.8s
# TSP30: Created 9000/30000 instances, elapsed 5.3s
# TSP30: Created 10000/30000 instances, elapsed 5.9s
# TSP30: Created 11000/30000 instances, elapsed 6.5s
# TSP30: Created 12000/30000 instances, elapsed 7.2s
# TSP30: Created 13000/30000 instances, elapsed 7.8s
# TSP30: Created 14000/30000 instances, elapsed 8.4s
# TSP30: Created 15000/30000 instances, elapsed 9.0s
# TSP30: Created 16000/30000 instances, elapsed 9.6s
# TSP30: Created 17000/30000 instances, elapsed 10.1s
# TSP30: Created 18000/30000 instances, elapsed 10.7s
# TSP30: Created 19000/30000 instances, elapsed 11.2s
# TSP30: Created 20000/30000 instances, elapsed 11.7s
# TSP30: Created 21000/30000 instances, elapsed 12.3s
# TSP30: Created 22000/30000 instances, elapsed 13.0s
# TSP30: Created 23000/30000 instances, elapsed 13.6s
# TSP30: Created 24000/30000 instances, elapsed 14.1s
# TSP30: Created 25000/30000 instances, elapsed 14.7s
# TSP30: Created 26000/30000 instances, elapsed 15.3s
# TSP30: Created 27000/30000 instances, elapsed 15.9s
# TSP30: Created 28000/30000 instances, elapsed 16.5s
# TSP30: Created 29000/30000 instances, elapsed 17.2s
# TSP30: Created 30000/30000 instances, elapsed 17.9s
# ✔ Finished TSP30, generated 30000 instances in 17.9s
#
# TSP40: Created 1000/30000 instances, elapsed 0.6s
# TSP40: Created 2000/30000 instances, elapsed 1.2s
# TSP40: Created 3000/30000 instances, elapsed 1.7s
# TSP40: Created 4000/30000 instances, elapsed 2.3s
# TSP40: Created 5000/30000 instances, elapsed 2.8s
# TSP40: Created 6000/30000 instances, elapsed 3.3s
# TSP40: Created 7000/30000 instances, elapsed 3.9s
# TSP40: Created 8000/30000 instances, elapsed 4.4s
# TSP40: Created 9000/30000 instances, elapsed 4.9s
# TSP40: Created 10000/30000 instances, elapsed 5.4s
# TSP40: Created 11000/30000 instances, elapsed 6.1s
# TSP40: Created 12000/30000 instances, elapsed 6.7s
# TSP40: Created 13000/30000 instances, elapsed 7.3s
# TSP40: Created 14000/30000 instances, elapsed 7.9s
# TSP40: Created 15000/30000 instances, elapsed 8.4s
# TSP40: Created 16000/30000 instances, elapsed 9.0s
# TSP40: Created 17000/30000 instances, elapsed 9.6s
# TSP40: Created 18000/30000 instances, elapsed 10.2s
# TSP40: Created 19000/30000 instances, elapsed 10.8s
# TSP40: Created 20000/30000 instances, elapsed 11.3s
# TSP40: Created 21000/30000 instances, elapsed 12.0s
# TSP40: Created 22000/30000 instances, elapsed 12.6s
# TSP40: Created 23000/30000 instances, elapsed 13.2s
# TSP40: Created 24000/30000 instances, elapsed 13.8s
# TSP40: Created 25000/30000 instances, elapsed 14.4s
# TSP40: Created 26000/30000 instances, elapsed 15.0s
# TSP40: Created 27000/30000 instances, elapsed 15.6s
# TSP40: Created 28000/30000 instances, elapsed 16.2s
# TSP40: Created 29000/30000 instances, elapsed 16.8s
# TSP40: Created 30000/30000 instances, elapsed 17.3s
# ✔ Finished TSP40, generated 30000 instances in 17.3s
#
# TSP50: Created 1000/30000 instances, elapsed 0.8s
# TSP50: Created 2000/30000 instances, elapsed 1.5s
# TSP50: Created 3000/30000 instances, elapsed 2.1s
# TSP50: Created 4000/30000 instances, elapsed 2.8s
# TSP50: Created 5000/30000 instances, elapsed 3.5s
# TSP50: Created 6000/30000 instances, elapsed 4.3s
# TSP50: Created 7000/30000 instances, elapsed 4.9s
# TSP50: Created 8000/30000 instances, elapsed 5.7s
# TSP50: Created 9000/30000 instances, elapsed 6.4s
# TSP50: Created 10000/30000 instances, elapsed 7.1s
# TSP50: Created 11000/30000 instances, elapsed 7.8s
# TSP50: Created 12000/30000 instances, elapsed 8.5s
# TSP50: Created 13000/30000 instances, elapsed 9.1s
# TSP50: Created 14000/30000 instances, elapsed 9.9s
# TSP50: Created 15000/30000 instances, elapsed 10.6s
# TSP50: Created 16000/30000 instances, elapsed 11.3s
# TSP50: Created 17000/30000 instances, elapsed 12.1s
# TSP50: Created 18000/30000 instances, elapsed 12.9s
# TSP50: Created 19000/30000 instances, elapsed 13.6s
# TSP50: Created 20000/30000 instances, elapsed 14.3s
# TSP50: Created 21000/30000 instances, elapsed 14.9s
# TSP50: Created 22000/30000 instances, elapsed 15.6s
# TSP50: Created 23000/30000 instances, elapsed 16.2s
# TSP50: Created 24000/30000 instances, elapsed 16.9s
# TSP50: Created 25000/30000 instances, elapsed 17.6s
# TSP50: Created 26000/30000 instances, elapsed 18.4s
# TSP50: Created 27000/30000 instances, elapsed 19.1s
# TSP50: Created 28000/30000 instances, elapsed 19.8s
# TSP50: Created 29000/30000 instances, elapsed 20.4s
# TSP50: Created 30000/30000 instances, elapsed 21.1s
# ✔ Finished TSP50, generated 30000 instances in 21.1s
