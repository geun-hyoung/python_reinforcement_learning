# %%
import os
import numpy as np
from scipy.spatial.distance import cdist

def parse_file(file_path, n=20):
    instances = []
    with open(file_path, 'r') as f:
        for line in f:
            tokens = line.strip().split()
            if "output" in tokens:
                idx = tokens.index("output")
                tokens = tokens[:idx]  # output 이전까지만 자르기
            try:
                coords_flat = list(map(float, tokens))
                if len(coords_flat) == 2 * n:
                    coords = np.array(coords_flat).reshape((n, 2))
                    instances.append(coords)
            except ValueError:
                continue
    return instances

def parse_file_with_optimal_tour(file_path, n=20):
    instances = []
    with open(file_path, 'r') as f:
        for line in f:
            tokens = line.strip().split()
            if "output" in tokens:
                idx = tokens.index("output")
                coords_flat = list(map(float, tokens[:idx]))
                tour = [int(x) - 1 for x in tokens[idx + 1:]]
                if len(coords_flat) == 2 * n and len(tour) == n + 1:
                    coords = np.array(coords_flat).reshape((n, 2))
                    instances.append((coords, tour))
    return instances

def save_distance_matrix_with_tour_txt(coords, tour, file_path):
    n = coords.shape[0]
    dist_matrix = cdist(coords, coords)
    dist_values = []
    for i in range(n):
        for j in range(i + 1, n):
            dist_values.append(dist_matrix[i, j])
    with open(file_path, 'w') as f:
        for val in dist_values:
            f.write(f"{val} ")
        f.write("output ")
        for node in tour:
            f.write(f"{node + 1} ")  # 다시 1-indexed로 저장
        f.write("\n")

input_path = os.path.join("dataset", "hw_2_tsp_20.txt")
instances_with_tour = parse_file_with_optimal_tour(input_path)

for i, (coords, tour) in enumerate(instances_with_tour, 1):
    file_path = os.path.join("dataset", f"20-{i}.txt")
    save_distance_matrix_with_tour_txt(coords, tour, file_path)

# %%
import os
import time
import numpy as np

# 설정
node_counts = [15]
num_samples = 50000
seed = 1234

np.random.seed(seed)

for n in node_counts:
    # 폴더 준비
    inst_dir = f"data/TSP{n}/instances"
    os.makedirs(inst_dir, exist_ok=True)

    start_all = time.time()
    for idx in range(num_samples):
        # 1) 무작위 좌표 생성
        coords = np.random.random((n, 2)).astype(np.float32)  # [0,1]^2

        # 2) 파일명 (5자리 zero-pad)
        fname = f"{idx:05d}"

        # 3) 좌표만 저장
        np.savez_compressed(
            os.path.join(inst_dir, f"instance_{fname}.npz"),
            coords=coords
        )

        # 4) 진행 로그 (예: 1000개마다)
        if (idx + 1) % 1000 == 0:
            elapsed = time.time() - start_all
            print(f"TSP{n}: Created {idx+1}/{num_samples} instances, elapsed {elapsed:.1f}s")

    total_time = time.time() - start_all
    print(f"✔ Finished TSP{n}, generated {num_samples} instances in {total_time:.1f}s\n")
# Out:
# TSP15: Created 1000/50000 instances, elapsed 0.3s
# TSP15: Created 2000/50000 instances, elapsed 0.6s
# TSP15: Created 3000/50000 instances, elapsed 1.0s
# TSP15: Created 4000/50000 instances, elapsed 1.3s
# TSP15: Created 5000/50000 instances, elapsed 1.7s
# TSP15: Created 6000/50000 instances, elapsed 2.1s
# TSP15: Created 7000/50000 instances, elapsed 2.4s
# TSP15: Created 8000/50000 instances, elapsed 2.8s
# TSP15: Created 9000/50000 instances, elapsed 3.2s
# TSP15: Created 10000/50000 instances, elapsed 3.5s
# TSP15: Created 11000/50000 instances, elapsed 3.8s
# TSP15: Created 12000/50000 instances, elapsed 4.1s
# TSP15: Created 13000/50000 instances, elapsed 4.4s
# TSP15: Created 14000/50000 instances, elapsed 4.8s
# TSP15: Created 15000/50000 instances, elapsed 5.1s
# TSP15: Created 16000/50000 instances, elapsed 5.4s
# TSP15: Created 17000/50000 instances, elapsed 5.7s
# TSP15: Created 18000/50000 instances, elapsed 6.1s
# TSP15: Created 19000/50000 instances, elapsed 6.4s
# TSP15: Created 20000/50000 instances, elapsed 6.7s
# TSP15: Created 21000/50000 instances, elapsed 7.0s
# TSP15: Created 22000/50000 instances, elapsed 7.3s
# TSP15: Created 23000/50000 instances, elapsed 7.6s
# TSP15: Created 24000/50000 instances, elapsed 7.9s
# TSP15: Created 25000/50000 instances, elapsed 8.2s
# TSP15: Created 26000/50000 instances, elapsed 8.5s
# TSP15: Created 27000/50000 instances, elapsed 8.8s
# TSP15: Created 28000/50000 instances, elapsed 9.1s
# TSP15: Created 29000/50000 instances, elapsed 9.4s
# TSP15: Created 30000/50000 instances, elapsed 9.7s
# TSP15: Created 31000/50000 instances, elapsed 10.0s
# TSP15: Created 32000/50000 instances, elapsed 10.4s
# TSP15: Created 33000/50000 instances, elapsed 10.7s
# TSP15: Created 34000/50000 instances, elapsed 11.0s
# TSP15: Created 35000/50000 instances, elapsed 11.3s
# TSP15: Created 36000/50000 instances, elapsed 11.6s
# TSP15: Created 37000/50000 instances, elapsed 12.0s
# TSP15: Created 38000/50000 instances, elapsed 12.3s
# TSP15: Created 39000/50000 instances, elapsed 12.6s
# TSP15: Created 40000/50000 instances, elapsed 12.9s
# TSP15: Created 41000/50000 instances, elapsed 13.3s
# TSP15: Created 42000/50000 instances, elapsed 13.6s
# TSP15: Created 43000/50000 instances, elapsed 13.9s
# TSP15: Created 44000/50000 instances, elapsed 14.2s
# TSP15: Created 45000/50000 instances, elapsed 14.5s
# TSP15: Created 46000/50000 instances, elapsed 14.9s
# TSP15: Created 47000/50000 instances, elapsed 15.2s
# TSP15: Created 48000/50000 instances, elapsed 15.5s
# TSP15: Created 49000/50000 instances, elapsed 15.9s
# TSP15: Created 50000/50000 instances, elapsed 16.2s
# ✔ Finished TSP15, generated 50000 instances in 16.2s
